# %% [markdown]
# ### Machine Learning Language Translation

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
import numpy as np

batch_size = 64 # batch size for training
epochs = 100 # number of epochs to train for
latent_dim = 256 # latent dimensionality of the encoding space
num_samples = 10000 # number of samples to train on

# Path to the data txt file on disk
data_path = 'fra.txt'

# %%
# vectorize the data
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()


with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

for line in lines[: min(num_samples, len(lines)-1)]:
    input_text, target_text, _ = line.split('\t')
    
    # we use 'tab' as the 'start sequence' character
    # for the targets, and '\n' as 'end sequence' character
    
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
            
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
# input_texts,target_texts,input_characters,target_characters

# %%
target_texts
# Out:
# ['\tVa !\n',
#  '\tMarche.\n',
#  '\tEn route !\n',
#  '\tBouge !\n',
#  '\tSalut !\n',
#  '\tSalut.\n',
#  '\tCours\u202f!\n',
#  '\tCourez\u202f!\n',
#  '\tPrenez vos jambes à vos cous !\n',
#  '\tFile !\n',
#  '\tFilez !\n',
#  '\tCours !\n',
#  '\tFuyez !\n',
#  '\tFuyons !\n',
#  '\tCours\u202f!\n',
#  '\tCourez\u202f!\n',
#  '\tPrenez vos jambes à vos cous !\n',
#  '\tFile !\n',
#  '\tFilez !\n',
#  '\tCours !\n',
#  '\tFuyez !\n',
#  '\tFuyons !\n',
#  '\tQui ?\n',
#  '\tÇa alors\u202f!\n',
#  '\tWaouh\xa0!\n',
#  '\tWah\xa0!\n',
#  '\tÀ terre\xa0!\n',
#  '\tBaisse-toi\xa0!\n',
#  '\tBaissez-vous\xa0!\n',
#  '\tAu feu !\n',
#  "\tÀ l'aide\u202f!\n",
#  '\tCache-toi.\n',
#  '\tCachez-vous.\n',
#  '\tSaute.\n',
#  '\tSaute.\n',
#  '\tÇa suffit\u202f!\n',
#  '\tStop\u202f!\n',
#  '\tArrête-toi !\n',
#  '\tAttends !\n',
#  '\tAttendez !\n',
#  '\tAttendez.\n',
#  '\tAttends !\n',
#  '\tAttendez !\n',
#  '\tAttends.\n',
#  '\tAttendez.\n',
#  '\tCommencez.\n',
#  '\tCommence.\n',
#  '\tPoursuis.\n',
#  '\tContinuez.\n',
#  '\tPoursuivez.\n',
#  '\tBonjour !\n',
#  '\tSalut !\n',
#  '\tBonjour !\n',
#  '\tSalut !\n',
#  '\tBonjour.\n',
#  '\tSalut.\n',
#  '\tJe comprends.\n',
#  '\tAha.\n',
#  "\tJ'essaye.\n",
#  "\tJ'ai gagné !\n",
#  "\tJe l'ai emporté !\n",
#  '\tJ’ai gagné.\n',
#  '\tOh non !\n',
#  '\tCalme-toi.\n',
#  '\tDétends-toi\u202f!\n',
#  '\tDétendez-vous\u202f!\n',
#  '\tRelaxe, Max\u202f!\n',
#  '\tCool, Raoul\u202f!\n',
#  '\tDu calme\u202f!\n',
#  '\tRelaxe !\n',
#  '\tCalmez-vous !\n',
#  '\tDétends-toi.\n',
#  '\tDétends-toi !\n',
#  '\tDu calme.\n',
#  '\tTranquille.\n',
#  '\tSouriez\u202f!\n',
#  '\tSouris pour la caméra.\n',
#  '\tSouriez\u2009!\n',
#  '\tPardon ?\n',
#  '\tAttaque !\n',
#  '\tAttaquez !\n',
#  "\tÀ l'attaque !\n",
#  "\tÀ l'attaque\xa0!\n",
#  '\tAchetez-la !\n',
#  '\tAchète-le !\n',
#  '\tAchetez-le !\n',
#  '\tAchète-la !\n',
#  '\tSanté !\n',
#  '\tÀ votre santé !\n',
#  '\tMerci !\n',
#  '\tTchin-tchin !\n',
#  '\tMangez-le.\n',
#  '\tMange-le.\n',
#  '\tExpire.\n',
#  '\tLève-toi.\n',
#  '\tLève-toi !\n',
#  '\tDebout.\n',
#  '\tVa, maintenant.\n',
#  '\tAllez-y maintenant.\n',
#  '\tVas-y maintenant.\n',
#  "\tJ'ai pigé !\n",
#  '\tCompris !\n',
#  '\tAha !\n',
#  '\tPigé\u202f?\n',
#  '\tCompris\u202f?\n',
#  "\tT'as capté\u202f?\n",
#  '\tMonte.\n',
#  '\tMontez.\n',
#  '\tSerre-moi dans tes bras !\n',
#  '\tSerrez-moi dans vos bras !\n',
#  '\tJe suis tombée.\n',
#  '\tJe suis tombé.\n',
#  "\tJ'ai fui.\n",
#  '\tJe chasse.\n',
#  '\tJe tricote.\n',
#  '\tJe sais.\n',
#  '\tJe suis parti.\n',
#  '\tJe suis partie.\n',
#  "\tJ'ai menti.\n",
#  "\tJ'ai perdu.\n",
#  '\tJe payais.\n',
#  '\tJe payai.\n',
#  '\tJ’ai payé.\n',
#  '\tJe passe.\n',
#  "\tJ'arrête.\n",
#  "\tJ'ai arrêté.\n",
#  '\tJe nage.\n',
#  "\tJ'ai 19 ans.\n",
#  '\tJe vais bien.\n',
#  '\tÇa va.\n',
#  '\tInspire.\n',
#  '\tÉcoutez !\n',
#  "\tC'est pas possible\u202f!\n",
#  '\tImpossible\u202f!\n',
#  '\tHors de question\u202f!\n',
#  '\tEn aucun cas.\n',
#  '\tSans façons\u202f!\n',
#  '\tMon œil\u202f!\n',
#  "\tC'est hors de question !\n",
#  "\tIl n'en est pas question !\n",
#  "\tC'est exclu !\n",
#  '\tEn aucune manière !\n',
#  '\tHors de question !\n',
#  '\tSans blague !\n',
#  '\tVraiment\u202f?\n',
#  '\tVrai ?\n',
#  '\tAh bon ?\n',
#  '\tAh vraiment ?\n',
#  '\tVraiment ?\n',
#  '\tMerci !\n',
#  '\tJe te remercie.\n',
#  '\tMerci !\n',
#  '\tMerci.\n',
#  '\tEssaie.\n',
#  '\tEssayez.\n',
#  '\tEssaye.\n',
#  '\tOn essaye.\n',
#  '\tNous avons gagné.\n',
#  '\tNous gagnâmes.\n',
#  "\tNous l'avons emporté.\n",
#  "\tNous l'emportâmes.\n",
#  '\tOn a gagné.\n',
#  '\tDemande à Tom.\n',
#  '\tDemande-lui.\n',
#  '\tFantastique\u202f!\n',
#  '\tSensass !\n',
#  '\tTrop cool !\n',
#  '\tGénial.\n',
#  '\tSois calme !\n',
#  '\tSoyez calme !\n',
#  '\tSoyez calmes !\n',
#  '\tSois détendu !\n',
#  '\tSois juste !\n',
#  '\tSoyez juste !\n',
#  '\tSoyez justes !\n',
#  '\tSois équitable !\n',
#  '\tSoyez équitable !\n',
#  '\tSoyez équitables !\n',
#  '\tSois honnête.\n',
#  '\tSois sincère.\n',
#  '\tSoyez honnêtes.\n',
#  '\tSois gentil.\n',
#  '\tSois gentil !\n',
#  '\tSois gentille !\n',
#  '\tSoyez gentil !\n',
#  '\tSoyez gentille !\n',
#  '\tSoyez gentils !\n',
#  '\tSoyez gentilles !\n',
#  '\tCassez-vous\xa0!\n',
#  '\tVa te faire foutre !\n',
#  '\tDégage\u202f!\n',
#  '\tCasse-toi.\n',
#  '\tPars !\n',
#  '\tFoutez le camp !\n',
#  '\tFous le camp !\n',
#  "\tPars d'ici.\n",
#  '\tVa-t’en\xa0!\n',
#  '\tDisparais !\n',
#  '\tFiche le camp.\n',
#  '\tTire-toi de là.\n',
#  '\tCasse-toi de là.\n',
#  '\tOust !\n',
#  '\tDégage.\n',
#  "\tFiche le camp d'ici.\n",
#  '\tDéguerpissez.\n',
#  '\tBouge !\n',
#  '\tDécampe !\n',
#  '\tBrûlez-le.\n',
#  '\tBrûlez-la.\n',
#  '\tBrûle-la.\n',
#  '\tBrûle-le.\n',
#  '\tEnterrez-le.\n',
#  '\tEnterre-le.\n',
#  '\tEnterrez-la.\n',
#  '\tEnterre-la.\n',
#  '\tAppelle-moi !\n',
#  '\tAppelez-moi\xa0!\n',
#  '\tAppelle-nous !\n',
#  '\tAppelez-nous !\n',
#  '\tEntrez\u202f!\n',
#  '\tEntre.\n',
#  '\tEntre !\n',
#  '\tEntrez !\n',
#  '\tAllez\u202f!\n',
#  '\tEn avant\u202f!\n',
#  '\tAllons !\n',
#  "\tC'est pas vrai, dis !\n",
#  '\tViens\xa0!\n',
#  '\tVenez\u202f!\n',
#  '\tSecouez-vous !\n',
#  '\tSecoue-toi !\n',
#  '\tAllez, on y va\xa0!\n',
#  '\tAllez !\n',
#  '\tViens\xa0!\n',
#  '\tVenez\u202f!\n',
#  '\tLaisse tomber !\n',
#  '\tLaissez tomber !\n',
#  '\tLaisse-le tomber !\n',
#  '\tLaissez-le tomber !\n',
#  '\tPliez-le.\n',
#  '\tPlie-le.\n',
#  '\tPliez-la.\n',
#  '\tPlie-la.\n',
#  '\tVa chercher Tom.\n',
#  '\tSors.\n',
#  '\tSortez\u202f!\n',
#  '\tDégage\u202f!\n',
#  '\tDisparais\u202f!\n',
#  '\tCasse-toi.\n',
#  '\tDégagez !\n',
#  '\tSors !\n',
#  '\tSortez !\n',
#  '\tDégage !\n',
#  '\tDisparais !\n',
#  '\tDu balai !\n',
#  '\tFiche le camp.\n',
#  '\tOust !\n',
#  "\tVers l'extérieur !\n",
#  '\tFichez le camp !\n',
#  '\tSortez.\n',
#  '\tDécampez !\n',
#  '\tDécampe !\n',
#  '\tSors.\n',
#  '\tSortez\u202f!\n',
#  '\tDégage\u202f!\n',
#  '\tDisparais\u202f!\n',
#  '\tCasse-toi.\n',
#  '\tDégagez !\n',
#  '\tSors !\n',
#  '\tSortez !\n',
#  '\tDisparais !\n',
#  '\tFiche le camp.\n',
#  '\tOust !\n',
#  '\tSortez.\n',
#  '\tBouge !\n',
#  '\tDécampez !\n',
#  '\tDécampe !\n',
#  '\tDégage\u202f!\n',
#  '\tPars !\n',
#  '\tAllez-vous-en\xa0!\n',
#  '\tDéguerpissez.\n',
#  '\tCassez-vous.\n',
#  '\tBouge !\n',
#  '\tDécampez !\n',
#  '\tDécampe !\n',
#  '\tVa te faire foutre !\n',
#  '\tPars !\n',
#  '\tDégage !\n',
#  '\tFous le camp !\n',
#  "\tPars d'ici.\n",
#  '\tVa-t’en\xa0!\n',
#  '\tDisparais !\n',
#  '\tDéguerpissez.\n',
#  '\tCassez-vous.\n',
#  '\tBouge !\n',
#  '\tDécampez !\n',
#  '\tDécampe !\n',
#  '\tAllez-vous-en.\n',
#  '\tRecule.\n',
#  '\tRentrez à la maison.\n',
#  '\tRentre à la maison.\n',
#  '\tRentre chez toi.\n',
#  '\tRentrez chez vous.\n',
#  '\tVa doucement !\n',
#  '\tAllez doucement !\n',
#  '\tAdieu !\n',
#  '\tÀ la revoyure.\n',
#  '\tCiao.\n',
#  '\tAu revoir.\n',
#  '\tCiao.\n',
#  '\tAttends un peu !\n',
#  '\tAttendez un peu !\n',
#  '\tAttendez.\n',
#  '\tTiens bon !\n',
#  '\tTenez bon !\n',
#  '\tAttendez.\n',
#  '\tIl est parti.\n',
#  '\tIl court.\n',
#  '\tAide-moi !\n',
#  "\tÀ l'aide\u202f!\n",
#  '\tAide-moi.\n',
#  '\tAidez-moi.\n',
#  '\tAide-moi !\n',
#  '\tAidez-nous !\n',
#  '\tAide-nous !\n',
#  '\tNe bouge plus !\n',
#  '\tNe bougez plus !\n',
#  '\tRestez où vous êtes !\n',
#  '\tAttendez.\n',
#  '\tNe quittez pas.\n',
#  '\tNe quitte pas !\n',
#  '\tTiens bon.\n',
#  '\tTenez bon.\n',
#  "\tComme c'est triste.\n",
#  '\tFais un câlin à Tom.\n',
#  '\tJe suis du même avis.\n',
#  "\tJ'ai pleuré.\n",
#  '\tJe me suis assoupi.\n',
#  '\tJe me suis assoupie.\n',
#  '\tJe conduis.\n',
#  '\tJe conduisis.\n',
#  "\tJ'ai tiré.\n",
#  '\tJe me suis figé.\n',
#  '\tJe me suis figée.\n',
#  '\tJe fume.\n',
#  '\tJe ronfle.\n',
#  '\tJe pue.\n',
#  '\tJe me suis tenu debout.\n',
#  '\tJe me suis tenue debout.\n',
#  '\tJ’ai promis.\n',
#  '\tJ’ai juré.\n',
#  "\tJ'essayai.\n",
#  "\tJ'ai essayé.\n",
#  "\tJ'ai tenté.\n",
#  '\tJ’ai fait signe.\n',
#  "\tJ'irai.\n",
#  '\tJe suis Tom.\n',
#  '\tJe suis gras.\n',
#  '\tJe suis gros.\n',
#  '\tJe suis en forme.\n',
#  '\tJe suis touché !\n',
#  '\tJe suis touchée !\n',
#  '\tJe suis malade.\n',
#  '\tJe suis fou.\n',
#  '\tJe suis folle.\n',
#  '\tJe suis en colère.\n',
#  '\tJe suis triste.\n',
#  "\tJ'ai un coup de cafard.\n",
#  '\tJe suis malheureux.\n',
#  '\tJe suis timide.\n',
#  '\tJe suis mouillé.\n',
#  '\tJe suis mouillée.\n',
#  "\tC'est bibi\u202f!\n",
#  '\tJoignez-vous.\n',
#  '\tJoignez-vous à nous.\n',
#  '\tGarde-le !\n',
#  '\tGardez-le !\n',
#  '\tDonne-lui un coup de pied.\n',
#  '\tDonnez-lui un coup de pied.\n',
#  '\tTuez-le.\n',
#  '\tTue-le.\n',
#  '\tTue-la.\n',
#  '\tTuez-la.\n',
#  '\tEmbrasse-moi.\n',
#  '\tEmbrassez-moi.\n',
#  '\tÀ terre !\n',
#  '\tAu sol !\n',
#  '\tVerrouillez-le.\n',
#  '\tVerrouille-le.\n',
#  '\tVerrouillez-la.\n',
#  '\tVerrouille-la.\n',
#  '\tLevez les yeux.\n',
#  '\tLève les yeux.\n',
#  '\tMoi aussi.\n',
#  '\tÀ moi aussi.\n',
#  '\tPassez à autre chose.\n',
#  '\tPasse à autre chose.\n',
#  '\tOuvrez-le.\n',
#  '\tOuvre-le.\n',
#  '\tOuvre-la.\n',
#  '\tOuvrez-la.\n',
#  '\tOuvre-moi\u202f!\n',
#  '\tOuvre.\n',
#  '\tFaites équipe.\n',
#  '\tParfait\u202f!\n',
#  '\tNickel\u202f!\n',
#  '\tParfait !\n',
#  '\tTirez dessus.\n',
#  '\tTire dessus.\n',
#  '\tAppuie dessus.\n',
#  '\tPoussez-le.\n',
#  '\tPousse-le.\n',
#  '\tPoussez-la.\n',
#  '\tPousse-la.\n',
#  '\tÀ plus tard\xa0!\n',
#  '\tÀ bientôt !\n',
#  '\tÀ la prochaine !\n',
#  '\tCiao.\n',
#  '\tÀ plus.\n',
#  '\tCiao.\n',
#  '\tMontre-moi !\n',
#  '\tMontrez-moi !\n',
#  '\tTaisez-vous\u202f!\n',
#  '\tFerme-la\u202f!\n',
#  '\tTais-toi !\n',
#  '\tFerme-la !\n',
#  '\tLa ferme !\n',
#  '\tBouclez-la !\n',
#  '\tFermez-la\xa0!\n',
#  '\tFerme-la\xa0!\n',
#  '\tInscrivez-vous.\n',
#  '\tInscris-toi.\n',
#  '\tLaisse tomber.\n',
#  '\tPas grave.\n',
#  '\tÀ plus tard\xa0!\n',
#  '\tPrends-le\u202f!\n',
#  '\tPrenez-le\u202f!\n',
#  '\tPrends-le !\n',
#  '\tPrenez-le !\n',
#  '\tPrenez-le.\n',
#  '\tPrends-le.\n',
#  '\tDis-moi !\n',
#  '\tDites-moi !\n',
#  '\tTom a gagné.\n',
#  '\tRéveille-toi\u202f!\n',
#  '\tRéveille-toi !\n',
#  '\tRéveillez-vous !\n',
#  '\tRéveille-toi !\n',
#  '\tRéveillez-vous !\n',
#  '\tLave-toi !\n',
#  '\tLavez-vous !\n',
#  '\tNous nous en soucions.\n',
#  '\tNous savons.\n',
#  '\tOn sait.\n',
#  '\tNous perdîmes.\n',
#  '\tNous avons perdu.\n',
#  '\tNous fûmes battus.\n',
#  '\tNous fûmes battues.\n',
#  '\tNous fûmes défaits.\n',
#  '\tNous fûmes défaites.\n',
#  '\tNous avons été défaits.\n',
#  '\tNous avons été défaites.\n',
#  '\tNous avons été battus.\n',
#  '\tNous avons été battues.\n',
#  '\tBienvenue\u202f!\n',
#  '\tSoyez le bienvenu !\n',
#  '\tQui courait\xa0?\n',
#  '\tQui a gagné ?\n',
#  "\tQui l'a emporté ?\n",
#  '\tTu cours.\n',
#  '\tVous avez gagné.\n',
#  '\tVisez haut.\n',
#  '\tVise haut.\n',
#  '\tSuis-je gros ?\n',
#  '\tSuis-je grosse ?\n',
#  '\tDemande-leur.\n',
#  '\tDemandez-leur.\n',
#  '\tRecule\u2009!\n',
#  '\tReculez.\n',
#  '\tCassez-vous.\n',
#  '\tRecule\u2009!\n',
#  '\tReculez.\n',
#  '\tRetire-toi\u2009!\n',
#  '\tRetirez-vous.\n',
#  '\tCassez-vous.\n',
#  '\tSois un homme !\n',
#  '\tSoyez un homme !\n',
#  '\tSoyez courageux !\n',
#  '\tSoyez bref.\n',
#  '\tSois bref.\n',
#  '\tSois brève.\n',
#  '\tSoyez brève.\n',
#  '\tSoyez brefs.\n',
#  '\tSoyez brèves.\n',
#  '\tSois calme !\n',
#  '\tSoyez calme !\n',
#  '\tSoyez calmes !\n',
#  '\tCasse-toi.\n',
#  '\tAppelle Tom.\n',
#  '\tAppelez Tom.\n',
#  '\tJe peux y aller\xa0?\n',
#  '\tCourage\u202f!\n',
#  '\tCourage\u202f!\n',
#  '\tDétends-toi\u202f!\n',
#  '\tCouvre-moi.\n',
#  '\tMenottez-le.\n',
#  '\tAvance !\n',
#  '\tAvancez !\n',
#  '\tContinue à rouler !\n',
#  '\tContinuez à rouler !\n',
#  '\tTrouve Tom.\n',
#  '\tTrouvez Tom.\n',
#  '\tRéparez ceci.\n',
#  '\tRépare ça.\n',
#  '\tDégage\u202f!\n',
#  '\tCasse-toi.\n',
#  '\tPars !\n',
#  '\tDégage !\n',
#  '\tFous le camp !\n',
#  "\tPars d'ici.\n",
#  '\tVa-t’en\xa0!\n',
#  '\tÉcarte-toi !\n',
#  '\tDisparais !\n',
#  '\tAllez-vous-en\xa0!\n',
#  '\tFiche le camp.\n',
#  '\tTire-toi de là.\n',
#  '\tDégage.\n',
#  "\tVa-t'en !\n",
#  "\tCriss ton camp d'icit !\n",
#  '\tFichez le camp.\n',
#  '\tDéguerpissez.\n',
#  '\tCassez-vous.\n',
#  '\tBarrez-vous.\n',
#  '\tBarre-toi.\n',
#  '\tVa-t’en !\n',
#  '\tBouge !\n',
#  '\tDécampez !\n',
#  '\tDécampe !\n',
#  '\tTu dis n’importe quoi\xa0!\n',
#  '\tPars.\n',
#  '\tPartez.\n',
#  '\tLâche-toi !\n',
#  '\tÀ terre !\n',
#  '\tAu sol !\n',
#  '\tDescends.\n',
#  '\tDescends !\n',
#  '\tDescendez !\n',
#  '\tLâche-toi !\n',
#  '\tLâchez-vous !\n',
#  '\tÀ terre !\n',
#  '\tAu sol !\n',
#  '\tDescends.\n',
#  "\tVa voir ailleurs si j'y suis\u202f!\n",
#  '\tDégage\u202f!\n',
#  '\tVa au diable !\n',
#  '\tDéguerpissez.\n',
#  '\tCassez-vous.\n',
#  '\tBouge !\n',
#  '\tDécampez !\n',
#  '\tDécampe !\n',
#  '\tVa te faire foutre\xa0!\n',
#  '\tVa te faire voir\xa0!\n',
#  '\tFiche le camp.\n',
#  '\tFichez le camp.\n',
#  '\tDéguerpissez.\n',
#  '\tCassez-vous.\n',
#  '\tBouge !\n',
#  '\tDécampez !\n',
#  '\tDécampe !\n',
#  '\tSois réaliste !\n',
#  '\tTu délires\xa0!\n',
#  '\tAllez\u202f!\n',
#  '\tVas-y.\n',
#  '\tEn avant\u202f!\n',
#  '\tVa !\n',
#  '\tPoursuis !\n',
#  '\tPoursuivez !\n',
#  '\tPasse devant !\n',
#  '\tVas-y !\n',
#  '\tAllez-y !\n',
#  '\tContinuez !\n',
#  '\tContinue !\n',
#  '\tAllez !\n',
#  '\tAvance !\n',
#  '\tEn avant\xa0!\n',
#  '\tAllez\u202f!\n',
#  '\tVas-y.\n',
#  '\tVa !\n',
#  '\tPoursuis !\n',
#  '\tPoursuivez !\n',
#  '\tPasse devant !\n',
#  '\tVas-y !\n',
#  '\tAllez-y !\n',
#  '\tContinuez !\n',
#  '\tContinue !\n',
#  '\tAllez !\n',
#  '\tAvance !\n',
#  '\tEn route !\n',
#  '\tBien joué\u202f!\n',
#  '\tBon boulot\u202f!\n',
#  '\tBeau travail\u202f!\n',
#  '\tBravo !\n',
#  '\tAttrape Tom.\n',
#  '\tAttrapez Tom.\n',
#  '\tAttrape-le.\n',
#  '\tAttrapez-le.\n',
#  '\tMettez-lui la main dessus !\n',
#  '\tAmuse-toi bien !\n',
#  '\tAmusez-vous bien !\n',
#  '\tAmuse-toi bien.\n',
#  '\tAmusez-vous bien.\n',
#  '\tIl a parlé.\n',
#  '\tIl a pris la parole.\n',
#  "\tIl s'est exprimé.\n",
#  '\tIl essaye.\n',
#  '\tIl est mouillé.\n',
#  '\tAide Tom.\n',
#  '\tAidez Tom.\n',
#  '\tAidez Tom !\n',
#  '\tSalut, les mecs !\n',
#  "\tComme c'est mignon\u202f!\n",
#  '\tTrop mignon !\n',
#  '\tTrop mignonne !\n',
#  '\tQuelle profondeur\u202f?\n',
#  '\tComme elle est belle\u202f!\n',
#  "\tComme c'est chouette !\n",
#  "\tComme c'est gentil !\n",
#  "\tC'est du joli !\n",
#  "\tComme c'est agréable !\n",
#  '\tQuelle grossièreté !\n',
#  '\tQuelle sagesse !\n',
#  '\tDépêche-toi.\n',
#  '\tGrouille\u202f!\n',
#  '\tPressez-vous !\n',
#  '\tFiça !\n',
#  '\tMagne-toi !\n',
#  '\tMagnez-vous !\n',
#  '\tJe suis Tom.\n',
#  "\tJ'ai juré.\n",
#  "\tJe m'en suis bien sorti.\n",
#  "\tJe m'en suis bien sortie.\n",
#  "\tJe l'ai fait.\n",
#  "\tC'est moi qui l'ai fait.\n",
#  "\tJ'ai échoué.\n",
#  "\tJ'ai oublié.\n",
#  "\tJ'ai compris.\n",
#  "\tJ'ai fait une gaffe.\n",
#  "\tJ'ai compris.\n",
#  "\tJ'ai capté.\n",
#  "\tJ'ai aidé.\n",
#  "\tJ'ai sauté.\n",
#  '\tJ’ai regardé.\n',
#  '\tJ’ai râlé.\n',
#  '\tJ’ai fait signe de la tête.\n',
#  '\tJ’ai obéi.\n',
#  '\tJe téléphonai.\n',
#  "\tJ'ai téléphoné.\n",
#  '\tJe refuse.\n',
#  '\tJe le refuse.\n',
#  '\tJe me suis reposé.\n',
#  '\tJe me suis reposée.\n',
#  "\tJe l'ai vu.\n",
#  '\tJe l’ai vu.\n',
#  '\tJ’ai soupiré.\n',
#  "\tJ'ai souri.\n",
#  '\tJe suis resté.\n',
#  '\tJe suis restée.\n',
#  '\tJ’ai parlé.\n',
#  "\tJe l'utilise.\n",
#  "\tJ'en fais usage.\n",
#  "\tJe m'en sers.\n",
#  '\tJe paierai.\n',
#  '\tJe paie.\n',
#  '\tJe vais essayer.\n',
#  "\tJ'essaierai.\n",
#  '\tJe suis revenu.\n',
#  '\tMe revoilà.\n',
#  '\tJe suis chauve.\n',
#  '\tJe suis occupé.\n',
#  '\tJe suis occupée.\n',
#  '\tJe suis calme.\n',
#  "\tJ'ai froid.\n",
#  '\tJe suis détendu.\n',
#  '\tJe suis détendue.\n',
#  '\tJe suis sourd.\n',
#  '\tJe suis sourde.\n',
#  "\tJ'en ai fini.\n",
#  '\tJe suis juste.\n',
#  "\tJ'ai la peau claire.\n",
#  "\tJ'ai le teint clair.\n",
#  '\tJe suis rapide.\n',
#  '\tTout va bien.\n',
#  '\tJe vais bien.\n',
#  '\tÇa va.\n',
#  '\tJe suis libre !\n',
#  '\tJe suis libre.\n',
#  '\tJe suis disponible.\n',
#  '\tJe suis repu\u202f!\n',
#  '\tJe suis rassasié\u202f!\n',
#  "\tJ'en suis.\n",
#  '\tJe suis de la partie.\n',
#  '\tJe suis content.\n',
#  '\tJe vais bien.\n',
#  '\tJe suis bon.\n',
#  '\tJe suis chez moi.\n',
#  '\tJe suis en retard.\n',
#  '\tJe suis paresseux.\n',
#  '\tJe suis fainéant.\n',
#  '\tJe suis paresseuse.\n',
#  '\tJe suis fainéante.\n',
#  '\tJe suis paumé.\n',
#  '\tJe suis perdue.\n',
#  '\tJe vais bien.\n',
#  '\tJe me porte bien.\n',
#  '\tJe suis riche.\n',
#  '\tJe suis en sécurité.\n',
#  '\tJe suis malade.\n',
#  "\tJ'en suis certain.\n",
#  '\tJe suis certain.\n',
#  "\tJ'en suis sûr.\n",
#  "\tJ'en suis sûre.\n",
#  '\tJe suis grande.\n',
#  '\tJe suis mince.\n',
#  '\tJe suis ordonné.\n',
#  '\tJe suis ordonnée.\n',
#  '\tJe suis laid.\n',
#  '\tJe suis laide.\n',
#  '\tJe suis moche.\n',
#  '\tJe suis faible.\n',
#  '\tJe vais bien.\n',
#  '\tJe me porte bien.\n',
#  "\tJ'ai gagné.\n",
#  "\tJe l'ai emporté.\n",
#  '\tÇa aide.\n',
#  '\tÇa fait mal.\n',
#  '\tElle marche.\n',
#  '\tÇa fonctionne.\n',
#  "\tC'est Tom.\n",
#  "\tC'est marrant.\n",
#  "\tC'est rigolo.\n",
#  "\tC'est le sien.\n",
#  "\tC'est la sienne.\n",
#  "\tC'est chaud.\n",
#  "\tC'est nouveau.\n",
#  "\tC'est neuf.\n",
#  "\tC'est bizarre.\n",
#  '\tIl est rouge.\n',
#  '\tC’est triste.\n',
#  "\tDéfense d'entrer.\n",
#  "\tN'entrez pas.\n",
#  '\tTuez Tom.\n',
#  '\tTue Tom.\n',
#  '\tEmbrasse Tom.\n',
#  '\tLaisse tomber !\n',
#  '\tLaissez tomber !\n',
#  '\tLaisse !\n',
#  '\tLaissez ça.\n',
#  '\tLaisse ça.\n',
#  '\tLaissez-moi !\n',
#  '\tLaisse-nous !\n',
#  '\tLaissez-nous !\n',
#  '\tAllons-y !\n',
#  '\tAllons !\n',
#  '\tEn route !\n',
#  '\tAllons-y !\n',
#  '\tEn route !\n',
#  '\tAttention !\n',
#  '\tFaites attention\u202f!\n',
#  '\tFais attention\u202f!\n',
#  '\tSoyez prudente !\n',
#  '\tFais gaffe !\n',
#  '\tFaites gaffe !\n',
#  '\tFais attention !\n',
#  '\tRegarde donc !\n',
#  '\tFaites attention.\n',
#  '\tFais attention.\n',
#  '\tÉpouse-moi !\n',
#  '\tÉpousez-moi !\n',
#  '\tPuis-je partir ?\n',
#  '\tPuis-je y aller ?\n',
#  "\tPuis-je m'y rendre ?\n",
#  '\tBelle tentative.\n',
#  '\tArrêtez-vous maintenant\xa0!\n',
#  '\tArrête-toi maintenant\xa0!\n',
#  '\tProuvez-le.\n',
#  '\tProuve-le.\n',
#  '\tFuyez.\n',
#  '\tFuis.\n',
#  '\tEnfuyez-vous.\n',
#  '\tEnfuis-toi.\n',
#  '\tSauve Tom.\n',
#  '\tSauvez Tom.\n',
#  '\tDe quoi\u202f?\n',
#  '\tElle est venue.\n',
#  '\tElle est morte.\n',
#  '\tElle est partie.\n',
#  '\tElle court.\n',
#  '\tAssieds-toi !\n',
#  '\tAsseyez-vous !\n',
#  '\tAsseyez-vous.\n',
#  '\tAssieds-toi.\n',
#  '\tAsseyez-vous.\n',
#  '\tAssieds-toi ici.\n',
#  '\tAsseyez-vous ici.\n',
#  '\tParle plus fort\u202f!\n',
#  '\tParlez plus fort\u202f!\n',
#  '\tParle plus fort !\n',
#  '\tAccélère.\n',
#  '\tAccélérez.\n',
#  '\tLève-toi.\n',
#  '\tArrête Tom.\n',
#  '\tStoppez Tom.\n',
#  '\tPrends Tom.\n',
#  '\tGoûte-le.\n',
#  '\tGoûte-la.\n',
#  '\tGoûtez-le.\n',
#  '\tGoûtez-la.\n',
#  '\tDis-le à Tom.\n',
#  '\tInformez-en Tom.\n',
#  '\tFantastique\u202f!\n',
#  '\tGénial\u202f!\n',
#  '\tSuper\u202f!\n',
#  '\tAu poil\u202f!\n',
#  '\tImpeccable\u202f!\n',
#  '\tNickel\u202f!\n',
#  '\tExcellent\u202f!\n',
#  '\tMagnifique\u202f!\n',
#  '\tNickel chrome\u202f!\n',
#  '\tBien.\n',
#  '\tFormidable !\n',
#  "\tC'est génial !\n",
#  '\tÀ la bonne heure !\n',
#  "\tC'est super.\n",
#  '\tSuper !\n',
#  '\tGénial !\n',
#  '\tSensass !\n',
#  '\tIls gagnèrent.\n',
#  '\tElles gagnèrent.\n',
#  '\tIls ont gagné.\n',
#  '\tElles ont gagné.\n',
#  '\tTom est venu.\n',
#  '\tTom est mort.\n',
#  '\tTom savait.\n',
#  '\tTom est parti.\n',
#  '\tTom partit.\n',
#  '\tTom a menti.\n',
#  '\tTom ment.\n',
#  '\tTom a perdu.\n',
#  '\tTom a payé.\n',
#  '\tTom payait.\n',
#  '\tTom est parti.\n',
#  '\tTom est debout.\n',
#  '\tTrop tard.\n',
#  '\tTouchez-le.\n',
#  '\tTouchez-la.\n',
#  '\tTouche-le.\n',
#  '\tTouche-la.\n',
#  '\tFais-moi confiance\u202f!\n',
#  '\tFaites-moi confiance.\n',
#  '\tFais-moi confiance.\n',
#  '\tAyez confiance en moi.\n',
#  '\tAie confiance en moi.\n',
#  '\tEssaies-en !\n',
#  '\tEssayez-en !\n',
#  '\tEssaie.\n',
#  '\tEssaie ceci !\n',
#  '\tEssayez ceci !\n',
#  '\tEssaye ceci.\n',
#  '\tUtilise ceci.\n',
#  '\tUtilisez ceci.\n',
#  '\tEmploie ceci !\n',
#  '\tEmployez ceci !\n',
#  '\tAvertis Tom.\n',
#  '\tPréviens Tom.\n',
#  '\tRegarde-moi !\n',
#  '\tRegardez-moi !\n',
#  '\tRegardez-nous !\n',
#  '\tRegarde-nous !\n',
#  "\tNous sommes d'accord.\n",
#  '\tNous irons.\n',
#  '\tNous allons bien.\n',
#  '\tPour quoi faire\u202f?\n',
#  '\tÀ quoi bon ?\n',
#  "\tQu'est-ce qu'on s'est marrés !\n",
#  "\tQu'est-ce qu'on s'est marrées !\n",
#  '\tQui suis-je ?\n',
#  '\tQui est venu ?\n',
#  '\tQui est mort ?\n',
#  '\tQui est tombé\xa0?\n',
#  '\tQui a perdu ?\n',
#  '\tQui a payé\xa0?\n',
#  '\tQui démissionne\xa0?\n',
#  '\tQui est-il\u202f?\n',
#  '\tÉcris-moi !\n',
#  '\tÉcrivez-moi !\n',
#  '\tTu as perdu.\n',
#  '\tVous avez perdu.\n',
#  '\tT’as perdu.\n',
#  '\tJe vous en prie.\n',
#  '\tAprès vous.\n',
#  '\tÀ vous l’honneur.\n',
#  '\tÀ toi l’honneur.\n',
#  '\tEn joue ! Feu !\n',
#  '\tSuis-je mignon ?\n',
#  '\tSuis-je en retard ?\n',
#  '\tRépondez-moi.\n',
#  '\tSois honnête.\n',
#  '\tSoyez honnêtes.\n',
#  '\tSoyez honnête.\n',
#  '\tAssieds-toi !\n',
#  '\tAsseyez-vous !\n',
#  '\tAsseyez-vous.\n',
#  '\tSois puissante\xa0!\n',
#  '\tLes oiseaux volent.\n',
#  '\tÀ tes souhaits\u202f!\n',
#  '\tAppelle à la maison !\n',
#  '\tCalmez-vous !\n',
#  '\tDu calme.\n',
#  '\tTranquille.\n',
#  '\tCalme-toi.\n',
#  '\tDu calme.\n',
#  '\tTranquille.\n',
#  '\tPouvons-nous partir ?\n',
#  '\tPouvons-nous nous en aller ?\n',
#  '\tPouvons-nous y aller ?\n',
#  '\tAttrape Tom.\n',
#  '\tAttrapez Tom.\n',
#  '\tAttrape-le\u202f!\n',
#  '\tRattrape-le.\n',
#  '\tSaisissez-le.\n',
#  '\tCalme-toi.\n',
#  '\tTranquille.\n',
#  '\tChoisis-moi !\n',
#  '\tReviens !\n',
#  '\tRevenez !\n',
#  '\tViens ici.\n',
#  '\tVenez là.\n',
#  '\tVenez ici !\n',
#  '\tViens chez nous !\n',
#  '\tVenez chez nous !\n',
#  '\tViens chez moi !\n',
#  '\tVenez chez moi !\n',
#  '\tViens bientôt !\n',
#  '\tVenez bientôt !\n',
#  '\tCalmez-vous !\n',
#  '\tAi-je gagné ?\n',
#  "\tL'ai-je emporté ?\n",
#  '\tEst-ce moi qui ai gagné ?\n',
#  '\tFaites-le maintenant.\n',
#  '\tDes chiens aboient.\n',
#  '\tLes chiens aboient.\n',
#  '\tNe demande pas !\n',
#  '\tNe pleure pas !\n',
#  '\tNe meurs pas !\n',
#  '\tNe mourez pas !\n',
#  '\tNe mens pas.\n',
#  '\tNe mens pas !\n',
#  '\tNe courez pas.\n',
#  '\tNe cours pas.\n',
#  '\tExcuse-moi.\n',
#  '\tExcusez-moi.\n',
#  '\tPardon\u202f?\n',
#  '\tJe vous demande pardon\u202f?\n',
#  '\tPlaît-il\u202f?\n',
#  '\tPlait-il\u202f?\n',
#  '\tPardon ?\n',
#  '\tFantastique\u202f!\n',
#  '\tFantastique\xa0!\n',
#  '\tSensass !\n',
#  '\tSens ça !\n',
#  '\tSentez ça !\n',
#  '\tTouche ça !\n',
#  '\tTouchez ça !\n',
#  '\tFilmez ceci.\n',
#  '\tFilme ceci.\n',
#  '\tSuis-moi.\n',
#  '\tSuis-nous !\n',
#  '\tSuivez-nous !\n',
#  '\tOublie !\n',
#  '\tOublie-le !\n',
#  '\tOubliez !\n',
#  '\tOubliez-le !\n',
#  '\tLaissez tomber.\n',
#  '\tOubliez ça !\n',
#  '\tLaisse tomber.\n',
#  '\tOublie.\n',
#  '\tOublie-le !\n',
#  '\tLaissez tomber.\n',
#  '\tOubliez ça !\n',
#  '\tOublie-moi.\n',
#  '\tOubliez-moi.\n',
#  '\tTrouve un emploi !\n',
#  '\tTrouve un boulot !\n',
#  '\tTrouvez un emploi !\n',
#  '\tTrouvez un boulot !\n',
#  '\tVa chercher une scie.\n',
#  '\tVas-y.\n',
#  '\tAllez-y.\n',
#  '\tMarche.\n',
#  '\tAvance.\n',
#  ...]

# %%
len(target_characters)
# Out:
# 93

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

# %%
# input_token_index, target_token_index

# %%
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t+1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestamp
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t>0:
            # decoder_target_data will be ahead by one timestamp
            # and will not include the start character
            decoder_target_data[i, t-1, target_token_index[char]] = 1.
    decoder_input_data[i, t+1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
# encoder_input_data
# decoder_input_data
# decoder_target_data

# %%
encoder_input_data[0].shape
# Out:
# (14, 70)

# %%
# define on input sentence and process it
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# we discard 'encoder_outputs' and only keep the states
encoder_states = [state_h, state_c]

# %%
# set up the decoder, using 'encoder_states' as initial state
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# we set up decoder to return full output sequences,
# and to return internal states as well. we don't use the 
# return states in the training model, but we will use them in inference
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# define the model that will turn
# 'encoder_input_data' & 'decoder_input_data' into 'decoder_target_data'
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
         batch_size=batch_size,
         epochs=epochs,
         validation_split=0.2)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 37s 264ms/step - loss: 1.2112 - accuracy: 0.7325 - val_loss: 1.0787 - val_accuracy: 0.7132
# Epoch 2/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.9386 - accuracy: 0.7485 - val_loss: 0.9700 - val_accuracy: 0.7257
# Epoch 3/100
# 125/125 [==============================] - 34s 270ms/step - loss: 0.8435 - accuracy: 0.7659 - val_loss: 0.8979 - val_accuracy: 0.7518
# Epoch 4/100
# 125/125 [==============================] - 34s 271ms/step - loss: 0.7505 - accuracy: 0.7900 - val_loss: 0.7839 - val_accuracy: 0.7738
# Epoch 5/100
# 125/125 [==============================] - 34s 269ms/step - loss: 0.6741 - accuracy: 0.8065 - val_loss: 0.7263 - val_accuracy: 0.7905
# Epoch 6/100
# 125/125 [==============================] - 34s 270ms/step - loss: 0.6312 - accuracy: 0.8169 - val_loss: 0.6841 - val_accuracy: 0.8008
# Epoch 7/100
# 125/125 [==============================] - 34s 268ms/step - loss: 0.6029 - accuracy: 0.8238 - val_loss: 0.6612 - val_accuracy: 0.8076
# Epoch 8/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.5797 - accuracy: 0.8298 - val_loss: 0.6476 - val_accuracy: 0.8093
# Epoch 9/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.5597 - accuracy: 0.8354 - val_loss: 0.6233 - val_accuracy: 0.8158
# Epoch 10/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.5415 - accuracy: 0.8407 - val_loss: 0.6030 - val_accuracy: 0.8228
# Epoch 11/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.5253 - accuracy: 0.8455 - val_loss: 0.5892 - val_accuracy: 0.8265
# Epoch 12/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.5086 - accuracy: 0.8505 - val_loss: 0.5759 - val_accuracy: 0.8306
# Epoch 13/100
# 125/125 [==============================] - 34s 276ms/step - loss: 0.4954 - accuracy: 0.8549 - val_loss: 0.5549 - val_accuracy: 0.8381
# Epoch 14/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.4814 - accuracy: 0.8589 - val_loss: 0.5498 - val_accuracy: 0.8383
# Epoch 15/100
# 125/125 [==============================] - 34s 271ms/step - loss: 0.4684 - accuracy: 0.8624 - val_loss: 0.5376 - val_accuracy: 0.8447
# Epoch 16/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.4574 - accuracy: 0.8657 - val_loss: 0.5234 - val_accuracy: 0.8474
# Epoch 17/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.4474 - accuracy: 0.8679 - val_loss: 0.5200 - val_accuracy: 0.8488
# Epoch 18/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.4381 - accuracy: 0.8708 - val_loss: 0.5096 - val_accuracy: 0.8511
# Epoch 19/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.4290 - accuracy: 0.8732 - val_loss: 0.5009 - val_accuracy: 0.8524
# Epoch 20/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.4208 - accuracy: 0.8753 - val_loss: 0.4982 - val_accuracy: 0.8542
# Epoch 21/100
# 125/125 [==============================] - 34s 276ms/step - loss: 0.4132 - accuracy: 0.8774 - val_loss: 0.4928 - val_accuracy: 0.8546
# Epoch 22/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.4058 - accuracy: 0.8795 - val_loss: 0.4921 - val_accuracy: 0.8547
# Epoch 23/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.3987 - accuracy: 0.8815 - val_loss: 0.4827 - val_accuracy: 0.8568
# Epoch 24/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.3922 - accuracy: 0.8835 - val_loss: 0.4749 - val_accuracy: 0.8593
# Epoch 25/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.3857 - accuracy: 0.8851 - val_loss: 0.4745 - val_accuracy: 0.8604
# Epoch 26/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.3800 - accuracy: 0.8866 - val_loss: 0.4670 - val_accuracy: 0.8632
# Epoch 27/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.3738 - accuracy: 0.8886 - val_loss: 0.4712 - val_accuracy: 0.8601
# Epoch 28/100
# 125/125 [==============================] - 35s 282ms/step - loss: 0.3673 - accuracy: 0.8903 - val_loss: 0.4634 - val_accuracy: 0.8633
# Epoch 29/100
# 125/125 [==============================] - 39s 316ms/step - loss: 0.3624 - accuracy: 0.8920 - val_loss: 0.4621 - val_accuracy: 0.8636
# Epoch 30/100
# 125/125 [==============================] - 35s 284ms/step - loss: 0.3566 - accuracy: 0.8934 - val_loss: 0.4581 - val_accuracy: 0.8645
# Epoch 31/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.3515 - accuracy: 0.8952 - val_loss: 0.4520 - val_accuracy: 0.8686
# Epoch 32/100
# 125/125 [==============================] - 35s 282ms/step - loss: 0.3459 - accuracy: 0.8969 - val_loss: 0.4518 - val_accuracy: 0.8677
# Epoch 33/100
# 125/125 [==============================] - 35s 282ms/step - loss: 0.3408 - accuracy: 0.8984 - val_loss: 0.4523 - val_accuracy: 0.8668
# Epoch 34/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.3359 - accuracy: 0.8997 - val_loss: 0.4479 - val_accuracy: 0.8684
# Epoch 35/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.3310 - accuracy: 0.9013 - val_loss: 0.4496 - val_accuracy: 0.8686
# Epoch 36/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.3265 - accuracy: 0.9025 - val_loss: 0.4462 - val_accuracy: 0.8694
# Epoch 37/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.3221 - accuracy: 0.9040 - val_loss: 0.4441 - val_accuracy: 0.8706
# Epoch 38/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.3173 - accuracy: 0.9058 - val_loss: 0.4423 - val_accuracy: 0.8713
# Epoch 39/100
# 125/125 [==============================] - 35s 282ms/step - loss: 0.3133 - accuracy: 0.9066 - val_loss: 0.4431 - val_accuracy: 0.8717
# Epoch 40/100
# 125/125 [==============================] - 35s 283ms/step - loss: 0.3088 - accuracy: 0.9080 - val_loss: 0.4393 - val_accuracy: 0.8727
# Epoch 41/100
# 125/125 [==============================] - 35s 279ms/step - loss: 0.3040 - accuracy: 0.9096 - val_loss: 0.4391 - val_accuracy: 0.8721
# Epoch 42/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.3000 - accuracy: 0.9105 - val_loss: 0.4388 - val_accuracy: 0.8723
# Epoch 43/100
# 125/125 [==============================] - 35s 277ms/step - loss: 0.2961 - accuracy: 0.9118 - val_loss: 0.4397 - val_accuracy: 0.8721
# Epoch 44/100
# 125/125 [==============================] - 35s 283ms/step - loss: 0.2918 - accuracy: 0.9129 - val_loss: 0.4374 - val_accuracy: 0.8742
# Epoch 45/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.2882 - accuracy: 0.9139 - val_loss: 0.4359 - val_accuracy: 0.8739
# Epoch 46/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.2840 - accuracy: 0.9153 - val_loss: 0.4393 - val_accuracy: 0.8737
# Epoch 47/100
# 125/125 [==============================] - 35s 278ms/step - loss: 0.2802 - accuracy: 0.9163 - val_loss: 0.4374 - val_accuracy: 0.8736
# Epoch 48/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.2768 - accuracy: 0.9167 - val_loss: 0.4358 - val_accuracy: 0.8750
# Epoch 49/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.2726 - accuracy: 0.9182 - val_loss: 0.4344 - val_accuracy: 0.8757
# Epoch 50/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.2695 - accuracy: 0.9192 - val_loss: 0.4363 - val_accuracy: 0.8755
# Epoch 51/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.2654 - accuracy: 0.9204 - val_loss: 0.4363 - val_accuracy: 0.8749
# Epoch 52/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.2622 - accuracy: 0.9213 - val_loss: 0.4363 - val_accuracy: 0.8757
# Epoch 53/100
# 125/125 [==============================] - 35s 278ms/step - loss: 0.2589 - accuracy: 0.9223 - val_loss: 0.4394 - val_accuracy: 0.8750
# Epoch 54/100
# 125/125 [==============================] - 35s 284ms/step - loss: 0.2552 - accuracy: 0.9234 - val_loss: 0.4353 - val_accuracy: 0.8757
# Epoch 55/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.2518 - accuracy: 0.9243 - val_loss: 0.4408 - val_accuracy: 0.8750
# Epoch 56/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.2484 - accuracy: 0.9256 - val_loss: 0.4374 - val_accuracy: 0.8761
# Epoch 57/100
# 125/125 [==============================] - 35s 279ms/step - loss: 0.2451 - accuracy: 0.9266 - val_loss: 0.4403 - val_accuracy: 0.8762
# Epoch 58/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.2416 - accuracy: 0.9274 - val_loss: 0.4414 - val_accuracy: 0.8759
# Epoch 59/100
# 125/125 [==============================] - 35s 280ms/step - loss: 0.2389 - accuracy: 0.9282 - val_loss: 0.4421 - val_accuracy: 0.8758
# Epoch 60/100
# 125/125 [==============================] - 36s 287ms/step - loss: 0.2357 - accuracy: 0.9289 - val_loss: 0.4402 - val_accuracy: 0.8770
# Epoch 61/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.2323 - accuracy: 0.9301 - val_loss: 0.4473 - val_accuracy: 0.8752
# Epoch 62/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.2292 - accuracy: 0.9308 - val_loss: 0.4468 - val_accuracy: 0.8757
# Epoch 63/100
# 125/125 [==============================] - 35s 281ms/step - loss: 0.2263 - accuracy: 0.9314 - val_loss: 0.4487 - val_accuracy: 0.8758
# Epoch 64/100
# 125/125 [==============================] - 35s 283ms/step - loss: 0.2232 - accuracy: 0.9328 - val_loss: 0.4470 - val_accuracy: 0.8772
# Epoch 65/100
# 125/125 [==============================] - 36s 289ms/step - loss: 0.2203 - accuracy: 0.9336 - val_loss: 0.4479 - val_accuracy: 0.8766
# Epoch 66/100
# 125/125 [==============================] - 36s 289ms/step - loss: 0.2174 - accuracy: 0.9344 - val_loss: 0.4536 - val_accuracy: 0.8762
# Epoch 67/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.2150 - accuracy: 0.9351 - val_loss: 0.4491 - val_accuracy: 0.8775
# Epoch 68/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.2121 - accuracy: 0.9359 - val_loss: 0.4527 - val_accuracy: 0.8767
# Epoch 69/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.2094 - accuracy: 0.9368 - val_loss: 0.4554 - val_accuracy: 0.8763
# Epoch 70/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.2067 - accuracy: 0.9375 - val_loss: 0.4556 - val_accuracy: 0.8772
# Epoch 71/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.2037 - accuracy: 0.9383 - val_loss: 0.4594 - val_accuracy: 0.8758
# Epoch 72/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.2017 - accuracy: 0.9390 - val_loss: 0.4563 - val_accuracy: 0.8775
# Epoch 73/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.1988 - accuracy: 0.9396 - val_loss: 0.4594 - val_accuracy: 0.8770
# Epoch 74/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1959 - accuracy: 0.9405 - val_loss: 0.4645 - val_accuracy: 0.8765
# Epoch 75/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1935 - accuracy: 0.9415 - val_loss: 0.4675 - val_accuracy: 0.8767
# Epoch 76/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1908 - accuracy: 0.9424 - val_loss: 0.4681 - val_accuracy: 0.8756
# Epoch 77/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1885 - accuracy: 0.9429 - val_loss: 0.4720 - val_accuracy: 0.8764
# Epoch 78/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1859 - accuracy: 0.9435 - val_loss: 0.4733 - val_accuracy: 0.8758
# Epoch 79/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1833 - accuracy: 0.9446 - val_loss: 0.4724 - val_accuracy: 0.8758
# Epoch 80/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1809 - accuracy: 0.9452 - val_loss: 0.4713 - val_accuracy: 0.8774
# Epoch 81/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1788 - accuracy: 0.9458 - val_loss: 0.4764 - val_accuracy: 0.8768
# Epoch 82/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1763 - accuracy: 0.9465 - val_loss: 0.4782 - val_accuracy: 0.8761
# Epoch 83/100
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1744 - accuracy: 0.9469 - val_loss: 0.4826 - val_accuracy: 0.8754
# Epoch 84/100
# 125/125 [==============================] - 35s 283ms/step - loss: 0.1720 - accuracy: 0.9479 - val_loss: 0.4842 - val_accuracy: 0.8756
# Epoch 85/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1703 - accuracy: 0.9481 - val_loss: 0.4849 - val_accuracy: 0.8759
# Epoch 86/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1679 - accuracy: 0.9489 - val_loss: 0.4873 - val_accuracy: 0.8753
# Epoch 87/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1657 - accuracy: 0.9496 - val_loss: 0.4925 - val_accuracy: 0.8758
# Epoch 88/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1635 - accuracy: 0.9503 - val_loss: 0.4966 - val_accuracy: 0.8750
# Epoch 89/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.1614 - accuracy: 0.9510 - val_loss: 0.4942 - val_accuracy: 0.8757
# Epoch 90/100
# 125/125 [==============================] - 35s 278ms/step - loss: 0.1599 - accuracy: 0.9512 - val_loss: 0.4982 - val_accuracy: 0.8747
# Epoch 91/100
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1576 - accuracy: 0.9520 - val_loss: 0.5054 - val_accuracy: 0.8747
# Epoch 92/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.1556 - accuracy: 0.9525 - val_loss: 0.5010 - val_accuracy: 0.8755
# Epoch 93/100
# 125/125 [==============================] - 35s 279ms/step - loss: 0.1538 - accuracy: 0.9531 - val_loss: 0.5088 - val_accuracy: 0.8750
# Epoch 94/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1522 - accuracy: 0.9536 - val_loss: 0.5062 - val_accuracy: 0.8758
# Epoch 95/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.1502 - accuracy: 0.9542 - val_loss: 0.5076 - val_accuracy: 0.8750
# Epoch 96/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.1485 - accuracy: 0.9547 - val_loss: 0.5108 - val_accuracy: 0.8743
# Epoch 97/100
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1466 - accuracy: 0.9554 - val_loss: 0.5162 - val_accuracy: 0.8747
# Epoch 98/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.1445 - accuracy: 0.9557 - val_loss: 0.5173 - val_accuracy: 0.8743
# Epoch 99/100
# 125/125 [==============================] - 34s 275ms/step - loss: 0.1430 - accuracy: 0.9560 - val_loss: 0.5215 - val_accuracy: 0.8749
# Epoch 100/100
# 125/125 [==============================] - 35s 283ms/step - loss: 0.1412 - accuracy: 0.9569 - val_loss: 0.5240 - val_accuracy: 0.8742

# %%
# next: inference mode (sampling)
# here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state and a 'start of sequence' token as target 
# and Output will be the next target token
# 3) Repeat with the current target token and current states

# define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state = decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# reverse-lookup token index to decode sequences back to something readable
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

def decode_sequence(input_seq):
    # encode the input as state vectors
    states_value = encoder_model.predict(input_seq, verbose=0)
    
    # generate empty target sequence of length 1
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    
    # populate the first character of target sequence with the start character
    target_seq[0, 0, target_token_index['\t']] = 1.
    
    # sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1)
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value, verbose=0)
    
        # sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # exit condition either hit max length
        # or find the stop character
        if (sampled_char == '\n' or 
           len(decoded_sentence)>max_decoder_seq_length):
            stop_condition = True

        # update the target sequence (of length 1)
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # update states
        states_value = [h, c]
    
    return decoded_sentence
    
for seq_index in range(100):
    # take one sequence (part of the training set)
    # for trying out decoding
    
    input_seq = encoder_input_data[seq_index: seq_index+1]
    decoded_sentence = decode_sequence(input_seq)
    
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Continuez !
#
# -
# Input sentence: Go.
# Decoded sentence: Continuez !
#
# -
# Input sentence: Go.
# Decoded sentence: Continuez !
#
# -
# Input sentence: Go.
# Decoded sentence: Continuez !
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# -
# Input sentence: Who?
# Decoded sentence: Qui sommes-nous ?
#
# -
# Input sentence: Wow!
# Decoded sentence: Attrons !
#
# -
# Input sentence: Wow!
# Decoded sentence: Attrons !
#
# -
# Input sentence: Wow!
# Decoded sentence: Attrons !
#
# -
# Input sentence: Duck!
# Decoded sentence: Maissez-vous !
#
# -
# Input sentence: Duck!
# Decoded sentence: Maissez-vous !
#
# -
# Input sentence: Duck!
# Decoded sentence: Maissez-vous !
#
# -
# Input sentence: Fire!
# Decoded sentence: Faissez ça.
#
# -
# Input sentence: Help!
# Decoded sentence: À l'aide !
#
# -
# Input sentence: Hide.
# Decoded sentence: Cachez-vous.
#
# -
# Input sentence: Hide.
# Decoded sentence: Cachez-vous.
#
# -
# Input sentence: Jump!
# Decoded sentence: Caissez-le.
#
# -
# Input sentence: Jump.
# Decoded sentence: Saute.
#
# -
# Input sentence: Stop!
# Decoded sentence: Attrapez-le !
#
# -
# Input sentence: Stop!
# Decoded sentence: Attrapez-le !
#
# -
# Input sentence: Stop!
# Decoded sentence: Attrapez-le !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attends !
#
# -
# Input sentence: Begin.
# Decoded sentence: Décherciz-vous.
#
# -
# Input sentence: Begin.
# Decoded sentence: Décherciz-vous.
#
# -
# Input sentence: Go on.
# Decoded sentence: Va chercher Tom.
#
# -
# Input sentence: Go on.
# Decoded sentence: Va chercher Tom.
#
# -
# Input sentence: Go on.
# Decoded sentence: Va chercher Tom.
#
# -
# Input sentence: Hello!
# Decoded sentence: Salut !
#
# -
# Input sentence: Hello!
# Decoded sentence: Salut !
#
# -
# Input sentence: Hello.
# Decoded sentence: Salut pour !
#
# -
# Input sentence: Hello.
# Decoded sentence: Salut pour !
#
# -
# Input sentence: Hello.
# Decoded sentence: Salut pour !
#
# -
# Input sentence: Hello.
# Decoded sentence: Salut pour !
#
# -
# Input sentence: I see.
# Decoded sentence: Je me suis reposée.
#
# -
# Input sentence: I see.
# Decoded sentence: Je me suis reposée.
#
# -
# Input sentence: I try.
# Decoded sentence: Je me suis faic pare.
#
# -
# Input sentence: I won!
# Decoded sentence: Je paut avanger.
#
# -
# Input sentence: I won!
# Decoded sentence: Je paut avanger.
#
# -
# Input sentence: I won.
# Decoded sentence: Je pais malade.
#
# -
# Input sentence: Oh no!
# Decoded sentence: Pours Tom.
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi !
#
# -
# Input sentence: Smile.
# Decoded sentence: Souriezsez-le.
#
# -
# Input sentence: Smile.
# Decoded sentence: Souriezsez-le.
#
# -
# Input sentence: Smile.
# Decoded sentence: Souriezsez-le.
#
# -
# Input sentence: Sorry?
# Decoded sentence: Déparderuou !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attentez !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attentez !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attentez !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attentez !
#
# -
# Input sentence: Buy it.
# Decoded sentence: Achetez-la !
#
# -
# Input sentence: Buy it.
# Decoded sentence: Achetez-la !
#
# -
# Input sentence: Buy it.
# Decoded sentence: Achetez-la !
#
# -
# Input sentence: Buy it.
# Decoded sentence: Achetez-la !
#
# -
# Input sentence: Cheers!
# Decoded sentence: À la faire noure !
#
# -
# Input sentence: Cheers!
# Decoded sentence: À la faire noure !
#
# -
# Input sentence: Cheers!
# Decoded sentence: À la faire noure !
#
# -
# Input sentence: Cheers!
# Decoded sentence: À la faire noure !
#
# -
# Input sentence: Eat it.
# Decoded sentence: Accucez-la !
#
# -
# Input sentence: Eat it.
# Decoded sentence: Accucez-la !
#
# -
# Input sentence: Exhale.
# Decoded sentence: Du calme.
#
# -
# Input sentence: Get up.
# Decoded sentence: Décalez !
#
# -
# Input sentence: Get up.
# Decoded sentence: Décalez !
#
# -
# Input sentence: Get up.
# Decoded sentence: Décalez !
#
# -
# Input sentence: Go now.
# Decoded sentence: Vas-y !
#
# -
# Input sentence: Go now.
# Decoded sentence: Vas-y !
#
# -
# Input sentence: Go now.
# Decoded sentence: Vas-y !
